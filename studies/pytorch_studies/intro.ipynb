# %% [markdown]
# <a href="https://colab.research.google.com/github/btretto03/Studies-for-Real-Time-Emotion-Recognition/blob/main/studies/pytorch_studies/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
#Just testing Google Colab and autosave in Github
